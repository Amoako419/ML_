# %%
import pandas as pd

# %%
tables = pd.read_html('https://en.wikipedia.org/wiki/List_of_Grammy_Award_winners_and_nominees_by_country')

# %%
len(tables)
# Out:
# 26

# %%
tables[1]
# Out:
#     Year                                              Award    Nominees  \
# 0   2008                                 Record of the Year  Rihanna[2]
# 1   2008                        Best Rap/Sung Collaboration  Rihanna[2]
# 2   2008                               Best Dance Recording  Rihanna[2]
# 3   2008  Best R&B Performance by a Duo or Group with Vo...  Rihanna[2]
# 4   2009                 Best Pop Collaboration with Vocals  Rihanna[2]
# 5   2009                               Best Dance Recording  Rihanna[2]
# 6   2009                         Best Long Form Music Video  Rihanna[2]
# 7   2010                                      Best Rap Song  Rihanna[2]
# 8   2010                        Best Rap/Sung Collaboration  Rihanna[2]
# 9   2011                        Best Rap/Sung Collaboration  Rihanna[2]
# 10  2011                                 Record of the Year  Rihanna[2]
# 11  2011                        Best Short Form Music Video  Rihanna[2]
# ...

# %%
tables[20]
# Out:
#    Year                              Category          Nominees(s)  \
# 0  2009                    Record of the Year           M.I.A.[60]
# 1  2013           Best Short Form Music Video           M.I.A.[60]
# 2  2014  Best Contemporary Instrumental Album  Herb Alpert [nb 11]
#
#        Nominated for     Result
# 0     "Paper Planes"  Nominated
# 1        "Bad Girls"  Nominated
# 2  Steppin' Out [61]        Won
